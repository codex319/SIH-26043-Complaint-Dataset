# %% [markdown]
# <a href="https://colab.research.google.com/github/codex319/SIH-26043-Complaint-Dataset/blob/main/Images_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in c:\users\bless\desktop\pandas\.conda\lib\site-packages (1.0.2)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.22 in c:\users\bless\desktop\pandas\.conda\lib\site-packages (from kagglehub) (0.1.34)
# Requirement already satisfied: packaging in c:\users\bless\desktop\pandas\.conda\lib\site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in c:\users\bless\desktop\pandas\.conda\lib\site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in c:\users\bless\desktop\pandas\.conda\lib\site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: tqdm in c:\users\bless\desktop\pandas\.conda\lib\site-packages (from kagglehub) (4.67.3)
# Requirement already satisfied: protobuf in c:\users\bless\desktop\pandas\.conda\lib\site-packages (from kagglesdk<1.0,>=0.1.22->kagglehub) (6.33.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\bless\desktop\pandas\.conda\lib\site-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bless\desktop\pandas\.conda\lib\site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bless\desktop\pandas\.conda\lib\site-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bless\desktop\pandas\.conda\lib\site-packages (from requests->kagglehub) (2025.10.5)
# Requirement already satisfied: colorama in c:\users\bless\desktop\pandas\.conda\lib\site-packages (from tqdm->kagglehub) (0.4.6)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("akinduhiman/urban-issues-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading to C:\Users\bless\.cache\kagglehub\datasets\akinduhiman\urban-issues-dataset\19.archive...
#  53%|█████▎    | 2.43G/4.53G [07:08<12:35, 3.00MB/s]

# %%
import os

print(os.listdir(path))
# Out:
# ['DamagedRoadSigns', 'Potholes and RoadCracks', 'FallenTrees', 'DamagedElectricalPoles', 'config.yaml', 'IllegalParking', 'Damaged concrete structures', 'Garbage', 'DeadAnimalsPollution', 'Graffitti']

# %%
import shutil

destination = "/content/urban_issues_dataset"

shutil.copytree(path, destination, dirs_exist_ok=True)

print("Dataset copied to:", destination)
# Out:
# Dataset copied to: /content/urban_issues_dataset

# %%
import kagglehub
import shutil
import os

# Download latest version
path = kagglehub.dataset_download("emmarex/plantdisease")

# Copy dataset to /content
destination = "/content/plantdisease"
shutil.copytree(path, destination, dirs_exist_ok=True)

print("Dataset saved at:", destination)
print("Files/Folders:", os.listdir(destination))
# Out:
# Using Colab cache for faster access to the 'plantdisease' dataset.
# Dataset saved at: /content/plantdisease
# Files/Folders: ['PlantVillage', 'plantvillage']

# %%
import kagglehub
import shutil
import os

# Download latest version
path = kagglehub.dataset_download("mostafaabla/garbage-classification")

# Copy dataset to /content
destination = "/content/garbage_classification"
shutil.copytree(path, destination, dirs_exist_ok=True)

print("Dataset saved at:", destination)
print("Files/Folders:", os.listdir(destination))
# Out:
# Using Colab cache for faster access to the 'garbage-classification' dataset.
# Dataset saved at: /content/garbage_classification
# Files/Folders: ['garbage_classification']

# %%
import kagglehub
import shutil
import os

# Download latest version
path = kagglehub.dataset_download(
    "adarshrouniyar/air-pollution-image-dataset-from-india-and-nepal"
)

# Copy dataset to /content
destination = "/content/air_pollution_images"

shutil.copytree(path, destination, dirs_exist_ok=True)

print("Dataset saved at:", destination)
print("Files/Folders:", os.listdir(destination))
# Out:
# Downloading to /root/.cache/kagglehub/datasets/adarshrouniyar/air-pollution-image-dataset-from-india-and-nepal/10.archive...
# 100%|██████████| 636M/636M [00:06<00:00, 99.4MB/s]
# Extracting files...
# Dataset saved at: /content/air_pollution_images
# Files/Folders: ['Readme.docx', 'Readme.txt', 'LIME_Explanation', 'LIME_20240506.best.hdf5', 'Dataset_for_AQI_Classification', 'Air Pollution Image Dataset']

# %%
import kagglehub
import shutil
import os

# Download latest version
path = kagglehub.dataset_download("kabeer2004/water-pollution-images")

# Copy dataset to /content
destination = "/content/water_pollution_images"

shutil.copytree(path, destination, dirs_exist_ok=True)

print("Dataset saved at:", destination)
print("Files/Folders:", os.listdir(destination))
# Out:
# Downloading to /root/.cache/kagglehub/datasets/kabeer2004/water-pollution-images/1.archive...
# 100%|██████████| 157M/157M [00:01<00:00, 111MB/s]
# Extracting files...
# Dataset saved at: /content/water_pollution_images
# Files/Folders: ['waterpollution']
